# %%
# importing required libraries

import numpy as np
from datetime import datetime
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import MaxPooling2D, Dense, Dropout, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.xception import Xception, preprocess_input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.utils import class_weight

# %%
print("TF version: ", tf.__version__)
print("GPU is ", "available" if tf.config.list_physical_devices("GPU") else "not available")
# Out:
# TF version:  2.8.0
# GPU is  available

# %%
# Data Paths
train_dir = r"D:\xception_model\Images\final_retrain_data\content\final_retrain_data\train"
test_dir = r"D:\xception_model\Images\final_retrain_data\content\final_retrain_data\test"
valid_dir = r"D:\xception_model\Images\final_retrain_data\content\final_retrain_data\validation"

# Checkpoint Paths
checkpoint_1_path = "checkpoint_1"
checkpoint_2_path = "checkpoint_2"

# Models Paths
model_1_path = "model"
model_path = "model_complete"

# Set hyperparameters
NUM_CLASSES = 6
INPUT_SHAPE = (299, 299, 3)
TARGET_SIZE = (299, 299)
BATCH_SIZE = 64
EPOCHS = 5

# %%
# Image Augmentation

train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    shear_range=0.2,
    zoom_range=0.2,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=TARGET_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True
)

valid_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

validation_generator = valid_datagen.flow_from_directory(
    valid_dir,
    target_size=TARGET_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

test_generator = valid_datagen.flow_from_directory(
    test_dir,
    target_size=TARGET_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 412576 images belonging to 6 classes.
# Found 53151 images belonging to 6 classes.
# Found 53178 images belonging to 6 classes.

# %%
class_indices = train_generator.class_indices

# %%
class_indices
# Out:
# {'explicit_moderation': 0,
#  'gore_moderation': 1,
#  'intoxicant_moderation': 2,
#  'sfw_moderation': 3,
#  'suggestive_moderation': 4,
#  'weapon_moderation': 5}

# %%
# Defining steps per epoch

TRAIN_STEPS = train_generator.n // BATCH_SIZE
VALID_STEPS = validation_generator.n // BATCH_SIZE

# %%
# Balancing the classes

class_weights = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=np.unique(train_generator.classes),
    y=train_generator.classes
)

class_weights = {i:w for i,w in enumerate(class_weights)}

# %%
from tensorflow.keras.models import Model

# Loading the pre-trained model
base_model = Xception(weights='imagenet', include_top=True, input_shape=INPUT_SHAPE)
base_model.summary()
# Out:
# Model: "xception"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_3 (InputLayer)           [(None, 299, 299, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 149, 149, 32  864         ['input_3[0][0]']
#                                 )
#
#  block1_conv1_bn (BatchNormaliz  (None, 149, 149, 32  128        ['block1_conv1[0][0]']
#  ation)                         )
#
#  block1_conv1_act (Activation)  (None, 149, 149, 32  0           ['block1_conv1_bn[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 147, 147, 64  18432       ['block1_conv1_act[0][0]']
#                                 )
#
#  block1_conv2_bn (BatchNormaliz  (None, 147, 147, 64  256        ['block1_conv2[0][0]']
#  ation)                         )
#
# ...

# %%
  
base_model = Model(inputs=base_model.input, outputs=base_model.layers[-2].output)
base_model.trainable = False
base_model.summary()
model = tf.keras.Sequential([
    base_model,
    Dense(128, activation='relu', kernel_initializer='he_normal'),
    Dropout(rate=0.5),
    Dense(NUM_CLASSES, activation='softmax')
])
# Compile Model
model.compile(optimizer=Adam(),
                       loss="categorical_crossentropy",
                       metrics=["accuracy", "CategoricalAccuracy", "Precision", "Recall"])
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_3 (InputLayer)           [(None, 299, 299, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 149, 149, 32  864         ['input_3[0][0]']
#                                 )
#
#  block1_conv1_bn (BatchNormaliz  (None, 149, 149, 32  128        ['block1_conv1[0][0]']
#  ation)                         )
#
#  block1_conv1_act (Activation)  (None, 149, 149, 32  0           ['block1_conv1_bn[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 147, 147, 64  18432       ['block1_conv1_act[0][0]']
#                                 )
#
#  block1_conv2_bn (BatchNormaliz  (None, 147, 147, 64  256        ['block1_conv2[0][0]']
#  ation)                         )
#
# ...

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  model_2 (Functional)        (None, 2048)              20861480
#
#  dense_4 (Dense)             (None, 128)               262272
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 6)                 774
#
# ...
# Total params: 21,124,526
# Trainable params: 263,046
# Non-trainable params: 20,861,480
# _________________________________________________________________

# %%
# Callbacks

# checkpoint_cb = ModelCheckpoint(checkpoint_1_path, save_weights_only=True)
# early_stopping_cb = EarlyStopping(patience=5, restore_best_weights=True)

# %%
# Callbacks

checkpoint_cb = ModelCheckpoint(filepath=checkpoint_1_path,
    save_weights_only=True,
    monitor='val_loss',
    mode='max',
    save_freq='epoch',
    save_best_only=True)

early_stopping_cb = EarlyStopping(patience=10, restore_best_weights=True)

# %% [raw]
# import os
#
# # Folder containing the images
# image_folder = r"D:\xception_model\Images\final_retrain_data\content\final_retrain_data\test\sfw_moderation"
#
# # List of image file extensions
# image_extensions = ('.jpg.jpg')
#
# # List to store names of image files
# image_names = []
#
# # Loop through the files in the folder
# for filename in os.listdir(image_folder):
#     if filename.lower().endswith(image_extensions):
#         image_names.append(filename)
#
# # Print the list of image names
# for name in image_names:
#     print(name)

# %% [raw]
# import os
#
# # Define the folder containing images
# image_folder = 'D:\\xception_model\\Images\\final_retrain_data\\content\\final_retrain_data\\test\\sfw_moderation\\'
#
# # List all files in the folder
# file_list = os.listdir(image_folder)
#
# for filename in file_list:
#     if filename.endswith(".jpg.jpg"):  # Ensure it's a .jpg.jpg file
#         old_path = os.path.join(image_folder, filename)
#         new_filename = filename[:-4]  # Remove only one occurrence of ".jpg"
#         new_path = os.path.join(image_folder, new_filename)
#         os.rename(old_path, new_path)
#
# print("Image filenames modified successfully!")

# %% [raw]
# import os
#
# # Define the folder containing images
# image_folder = 'D:\\xception_model\\Images\\final_retrain_data\\content\\final_retrain_data\\test\\sfw_moderation\\'
#
# # List all files in the folder
# file_list = os.listdir(image_folder)
#
# for filename in file_list:
#     if filename.endswith(".jpg.jpg"):  # Ensure it's a .jpg.jpg file
#         new_filename = filename[:-4]  # Remove the last occurrence of ".jpg"
#         new_path = os.path.join(image_folder, new_filename)
#         os.rename(os.path.join(image_folder, filename), new_path)
#
# print("Image filenames modified successfully!")

# %%
from datetime import datetime
import PIL

try:
    # Training the model
    start = datetime.now()

    history = model.fit(
        train_generator,
        steps_per_epoch=TRAIN_STEPS,
        validation_data=validation_generator,
        validation_steps=VALID_STEPS,
        epochs=EPOCHS,
        class_weight=class_weights,
        callbacks=[checkpoint_cb])

    end = datetime.now()
    print(f"Execution time: {(end-start)}")

    # saving the model
    model.save(model_1_path, save_format="tf")

except PIL.UnidentifiedImageError as e:
    print("Error: UnidentifiedImageError")
    # Handle the exception here, e.g., print the problematic image file name, skip it, or take any other appropriate action.
    # For example, you can inspect the image file path by accessing `e.args[0]`.
except Exception as e:
    # Handle any other unexpected exceptions here, if needed.
    print(f"An error occurred: {e}")
# Out:
# Epoch 1/100
# 2696/6446 [===========>..................] - ETA: 2:13:17 - loss: 0.7487 - accuracy: 0.7097 - categorical_accuracy: 0.7097 - precision: 0.7930 - recall: 0.6006
# C:\Users\DATA\anaconda3\envs\nsfw_image\lib\site-packages\PIL\Image.py:3157: DecompressionBombWarning: Image size (144639000 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 4207/6446 [==================>...........] - ETA: 1:18:37 - loss: 0.7123 - accuracy: 0.7226 - categorical_accuracy: 0.7226 - precision: 0.8021 - recall: 0.6200
# C:\Users\DATA\anaconda3\envs\nsfw_image\lib\site-packages\PIL\Image.py:3157: DecompressionBombWarning: Image size (125846000 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 4739/6446 [=====================>........] - ETA: 1:00:16 - loss: 0.7038 - accuracy: 0.7252 - categorical_accuracy: 0.7252 - precision: 0.8037 - recall: 0.6243
# ...

# %%
# Loading the model weights from checkpoint
model.load_weights(r'D:\xception_model\checkpoint_1')

# %%
model.save(r'D:\xception_model\model', save_format="tf")

# %%
# Compile Model
model.compile(optimizer=Adam(),
                       loss="categorical_crossentropy",
                       metrics=["accuracy", "CategoricalAccuracy", "Precision", "Recall"])

# %%
from datetime import datetime
import PIL

try:
    # Training the model
    start = datetime.now()

    history = model.fit(
        train_generator,
        steps_per_epoch=TRAIN_STEPS,
        validation_data=validation_generator,
        validation_steps=VALID_STEPS,
        epochs=EPOCHS,
        class_weight=class_weights,
        callbacks=[checkpoint_cb])

    end = datetime.now()
    print(f"Execution time: {(end-start)}")

    # saving the model
    model.save(model_1_path, save_format="tf")

except PIL.UnidentifiedImageError as e:
    print("Error: UnidentifiedImageError")
    # Handle the exception here, e.g., print the problematic image file name, skip it, or take any other appropriate action.
    # For example, you can inspect the image file path by accessing `e.args[0]`.
except Exception as e:
    # Handle any other unexpected exceptions here, if needed.
    print(f"An error occurred: {e}")
# Out:
# Epoch 1/5
#   73/6446 [..............................] - ETA: 2:51:26 - loss: 0.4288 - accuracy: 0.8343 - categorical_accuracy: 0.8343 - precision: 0.8678 - recall: 0.8080
# C:\Users\DATA\anaconda3\envs\nsfw_image\lib\site-packages\PIL\Image.py:3157: DecompressionBombWarning: Image size (133330000 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
#  577/6446 [=>............................] - ETA: 2:40:17 - loss: 0.4340 - accuracy: 0.8098 - categorical_accuracy: 0.8098 - precision: 0.8536 - recall: 0.7717
# C:\Users\DATA\anaconda3\envs\nsfw_image\lib\site-packages\PIL\Image.py:3157: DecompressionBombWarning: Image size (100000000 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 2807/6446 [============>.................] - ETA: 1:39:51 - loss: 0.4298 - accuracy: 0.8055 - categorical_accuracy: 0.8055 - precision: 0.8528 - recall: 0.7623
# ...

# %%
model.save(r'D:\xception_model\model_complete', save_format="tf")
# Out:
# INFO:tensorflow:Assets written to: D:\xception_model\model_complete\assets

# %%
# Evaluating the model on test set

metrics = model.evaluate(test_generator)
print(len(metrics))
metrics
# Out:
# 831/831 [==============================] - 555s 667ms/step - loss: 0.3996 - accuracy: 0.8555 - categorical_accuracy: 0.8555 - precision: 0.8789 - recall: 0.8326
# 5
# [0.39956042170524597,
#  0.8554665446281433,
#  0.8554665446281433,
#  0.8789082169532776,
#  0.8325811624526978]

# %%
try:
  history_df = pd.DataFrame(history.history)
  history_df.to_csv('xception_result_1.xlsx')
except:
  pass

# %%
test_data= test_generator

# %%
class_names = test_generator.class_indices

# %%
class_names.keys()
# Out:
# dict_keys(['explicit_moderation', 'gore_moderation', 'intoxicant_moderation', 'sfw_moderation', 'suggestive_moderation', 'weapon_moderation'])

# %%
import numpy as np

# Get the number of test samples
num_test_samples = len(test_generator)

# Generate predictions
predictions = xception_model.predict(test_generator, steps=num_test_samples)

# Get the true labels from the test generator
true_labels = test_generator.classes

# %%
from sklearn.metrics import confusion_matrix

# Convert predicted labels to class indices
predicted_labels = np.argmax(predictions, axis=1)

# Build the confusion matrix
cm = confusion_matrix(true_labels, predicted_labels)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(cm,
            annot=True,
            fmt='g',
            xticklabels=class_names.keys(),
            yticklabels=class_names.keys(),
    )
plt.ylabel('Prediction',fontsize=13)
plt.xlabel('Actual',fontsize=13)
plt.title('Confusion Matrix',fontsize=17)
plt.show()

# %%
# Upload the model in the s3
def upload_s3():
    file_path = 'D:/xception_model/xceptionmodel_complete(29_08).zip'
    s3_key = 'spam_detection_new/spam_images/models/xceptionmodel_complete(29_08).zip'
    configs = Properties()
    with open('app-config.properties', 'rb') as config_file:
        configs.load(config_file)
    access_key = configs.get("aws_access_key_id")[0]
    secret_access_key = configs.get("aws_secret_access_key")[0]
    bucket = configs.get("s3_bucket_name")[0]
    region = configs.get("region_name")[0]

    s3_client = boto3.client('s3',
                              aws_access_key_id= access_key,
                            aws_secret_access_key=secret_access_key,
                              region_name=region)

    # Upload the file to S3 bucket
    s3_client.upload_file(file_path, bucket, s3_key)
    
    print("File uploaded successfully.")

# %%
upload_s3()
# Out:
# File uploaded successfully.

# %%
import json
from io import BytesIO
from PIL import Image
#from datetime import datetime
from jproperties import Properties
from numpy import array as numpy_array
import boto3
import tensorflow as tf
import numpy as np


model_path = "model_complete"
model = tf.keras.models.load_model(model_path)

class_names = ['explicit_moderation', 'gore_moderation', 'intoxicants_moderation', 'sfw_moderation', 'suggestive_moderation', 'weapons_moderation']

#S3connection
configs = Properties()
with open('/content/drive/MyDrive/app-config.properties', 'rb') as config_file:
    configs.load(config_file)
access_key = configs.get("aws_access_key_id")[0]
secret_access_key = configs.get("aws_secret_access_key")[0]
bucket = configs.get("s3_bucket_name")[0]
region = configs.get("region_name")[0]

s3_client = boto3.client('s3',aws_access_key_id= access_key,
                        aws_secret_access_key=secret_access_key,region_name=region)

def get_img_from_s3(image_path, img_type='other'):
    file_byte_string = s3_client.get_object(Bucket=bucket, Key=image_path)['Body'].read()
    image = Image.open(BytesIO(file_byte_string))
    image = image.resize((299, 299))
    return image

def get_predictions(image_path_lst):
    pred_lst = []
    category = []
    for image_path in image_path_lst:
        prediction_dict = {}
        # Loading image
        try:
            image = get_img_from_s3(image_path)
        except Exception as e:
            prediction_dict["image_path"] = image_path
            prediction_dict["class_label"] = None
            prediction_dict["confidence"] = None
            prediction_dict["error"] = "The specified key does not exist." #e["response"]["Error"]["Message"]
            pred_lst.append(prediction_dict)
            continue
        image = tf.keras.preprocessing.image.img_to_array(image)
        image = image / 255.0  # Normalize the image
        # Expand dimensions to match the input tensor shape
        image = np.expand_dims(image, axis=0)
        # Make predictions
        predictions = model.predict(image)
        # Process the predictions
        predicted_class_index = np.argmax(predictions[0])
        prediction_dict["image_path"] = image_path
        prediction_dict["class_label"] = class_names[predicted_class_index]
        category.append(class_names[predicted_class_index])
        prediction_dict["confidence"] = float(predictions[0][predicted_class_index])
        pred_lst.append(prediction_dict)
    category = list(filter(lambda x: x is not None, category))
    if len(category)==0:
        final_output = "No images found"
    elif any(element != 'sfw_moderation' for element in category):
        final_output = "spam"
    else:
        final_output = "ham"
    #pred_lst.append({'final_output':final_output})
    #return pred_lst
    return pred_lst

# %%
image_path_lst= ["images/nature.jpg"]

get_predictions(image_path_lst)
